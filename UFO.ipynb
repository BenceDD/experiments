# %% [markdown]
# # UFO észlelések vizualizálása

# %% [markdown]
# Az adatokat a ```pandas``` segtségével kezeltem, a vizualizációt pedig a ```plotly``` segítségével csináltam.

# %%
import pandas as pd
import plotly.offline as py
from sklearn.preprocessing import MinMaxScaler
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ### Az UFO észlelési adatok előkészítése
# Az UFO észleléseket előzetesen letöltöttem egy állományba. A forrás: http://www.nuforc.org/webreports/

# %%
ufos = pd.read_json('../Big-Data-UFO1-homework/data.json')
ufos.columns = ufos.columns.str.lower()  # set all attribures to lower case
ufos.head()
# Out:
#          city           date    duration   posted      shape state  \
# 0   St. Louis  11/9/17 04:30      1 hour  11/9/17    Unknown    MO
# 1       Paola  11/9/17 01:00     2 hours  11/9/17     Circle    KS
# 2   Tontitown  11/8/17 22:20   2 minutes  11/9/17     Circle    AR
# 3    Loveland  11/8/17 20:50  20 minutes  11/9/17   Changing    CO
# 4  Plainville  11/8/17 20:35   5 minutes  11/9/17  Formation    CT
#
#                                              summary              link
# 0  White lights with a red pulsating strobe in a ...  137/S137177.html
# 1  Im sitting by my window smoking and happen to ...  137/S137178.html
# 2                            Large solid white ball.  137/S137176.html
# 3  5 glimmering stationary objects for 20 minutes...  137/S137180.html
# 4  Nov 8 at approx 8:35 pm driving west on rte 37...  137/S137181.html

# %% [markdown]
# A ```summary``` és a ```link``` mezőkre most nem lesz szükség.

# %%
ufos.drop(columns=['summary', 'link'], inplace=True)

# %% [markdown]
# Kérdés, hogy milyen típusúak az az attribútumok és hogy tartalmaznak-e NULL értékeket.

# %%
pd.DataFrame({'null': ufos.isnull().any(), 'types': ufos.dtypes})
# Out:
#            null   types
# city      False  object
# date      False  object
# duration  False  object
# posted    False  object
# shape     False  object
# state     False  object

# %% [markdown]
# Bár a mezők sehol sem tartalmaznak ```null```-t, mivel ```object``` típusúak, ezért még tartalmazhatnak azzal elvivalens értékeket.
#
# Mivel a ```Date``` mező jelenleg nem dátum formátumú, ezért átalakítom arra. Nem mindenhol sikerült, ezért megnézem hogy ahol nem sikerült, ott miért nem (a ```coerce``` kapcsoló ```null```-t tesz a sikertelen parsolás helyére.)

# %%
ufos['date_parsed'] = pd.to_datetime(ufos['date'], errors='coerce')
ufos[ufos['date_parsed'].isnull()].head()
# Out:
#                city        date    duration    posted shape state date_parsed
# 553         Olympia  md 9 10:10   2 minutes  10/19/17          WA         NaT
# 827      Hellertown               2 seconds   9/28/17          PA         NaT
# 1172        Copalis                            9/5/17          WA         NaT
# 2187  Shepherdstown              10 minutes    7/7/17  Oval    WV         NaT
# 2929  Atlantic City    4/ 23:22  30 minutes    5/6/17  Disk    NJ         NaT

# %% [markdown]
# Úgy tűnik hogy a forrásban nem szabványos módon is vannak tárolva dátumok, illetve van ahol nincs is kitöltve.
#
# A ```City``` mező sok helyen zárójelek között tartalmaz egyéb földrajzi információkat, amelyeket eltávolítok a sorok végéről. Az így kapott neveket a ```City_cleaned``` változóba teszem el és a továbbiakban ezt használom a városok azonosítására.

# %%
ufos['city_cleaned'] = ufos['city'].str.replace(r'[(][A-Za-z/]*[)]$', '').str.rstrip()
ufos[ufos['city_cleaned'] != ufos['city']].head()
# Out:
#                         city            date       duration   posted  \
# 13          Pueblo (Belmont)   11/7/17 17:15       1 minute  11/9/17
# 21         Acol (UK/England)   11/6/17 19:45  Still ongoing  11/9/17
# 32       Highway 60 (Canada)   11/5/17 19:38       1 second  11/9/17
# 64        Athabasca (Canada)  10/27/17 17:30      4 seconds  11/9/17
# 69  New York City (Brooklyn)    8/4/17 00:00     20 minutes  11/9/17
#
#         shape state         date_parsed   city_cleaned
# 13      Other    CO 2017-11-07 17:15:00         Pueblo
# 21      Flash       2017-11-06 19:45:00           Acol
# 32     Circle    MB 2017-11-05 19:38:00     Highway 60
# 64  Rectangle    AB 2017-10-27 17:30:00      Athabasca
# 69  Formation    NY 2017-08-04 00:00:00  New York City

# %% [markdown]
# ### Az USA város listájának előkészítése
# Az USA városainak listája: https://simplemaps.com/data/us-cities

# %%
cities = pd.read_csv('../Big-Data-UFO1-homework/uscitiesv1.4.csv')
cities.head()
# Out:
#              city      city_ascii state_id  state_name  county_fips  \
# 0   Prairie Ridge   Prairie Ridge       WA  Washington        53053
# 1          Edison          Edison       WA  Washington        53057
# 2        Packwood        Packwood       WA  Washington        53041
# 3  Wautauga Beach  Wautauga Beach       WA  Washington        53035
# 4          Harper          Harper       WA  Washington        53035
#
#   county_name      lat       lng  population  population_proper  density  \
# 0      Pierce  47.1443 -122.1408         NaN                NaN   1349.8
# 1      Skagit  48.5602 -122.4311         NaN                NaN    127.4
# 2       Lewis  46.6085 -121.6702         NaN                NaN    213.9
# 3      Kitsap  47.5862 -122.5482         NaN                NaN    261.7
# 4      Kitsap  47.5207 -122.5196         NaN                NaN    342.1
#
#     source  incorporated             timezone         zips          id
# 0  polygon         False  America/Los_Angeles  98360 98391  1840037882
# 1  polygon         False  America/Los_Angeles        98232  1840017314
# 2  polygon         False  America/Los_Angeles        98361  1840025265
# 3    point         False  America/Los_Angeles        98366  1840037725
# 4    point         False  America/Los_Angeles        98366  1840037659

# %% [markdown]
# Törlöm a fölösleges attribútumokat. (Az egyes attribútumok pontos jelentése a fenti linken elérhető.)

# %%
cities.drop(columns=['county_fips', 'source', 'zips', 'id'], inplace=True)

# %% [markdown]
# Kérdés, hogy milyen típusúak az az attribútumok és hogy tartalmaznak-e NULL értékeket.

# %%
pd.DataFrame({'null': cities.isnull().any(), 'types': cities.dtypes})
# Out:
#                     null    types
# city               False   object
# city_ascii         False   object
# state_id           False   object
# state_name         False   object
# county_name        False   object
# lat                False  float64
# lng                False  float64
# population          True  float64
# population_proper   True  float64
# density            False  float64
# incorporated       False     bool
# timezone            True   object

# %% [markdown]
# Látszik, hogy lokációs adatok mindenhol szerepelnek, viszont a populáció nem. TODO: Azokat a városokat is törölnöm kell. Hasonlóan az 5 főnél kisebb lélekszámú településeket.

# %% [markdown]
# ### Az adatok összefésülése az UFO észlelések helyének ellenőrzésére
# A két táblát a ```City_cleaned``` és a ```State``` mező mentén szeretném összefésülni. A ```City``` mezőt már az észlelések előkészítésénél kitisztítottam, most a ```State``` mezőt nézem meg.

# %%
set(ufos['state'].unique()) - set(cities['state_id'].unique())
# Out:
# {'',
#  'AB',
#  'BC',
#  'Ca',
#  'Fl',
#  'MB',
#  'NB',
#  'NF',
#  'NS',
#  'NT',
#  'ON',
#  'PE',
#  'PQ',
#  'QC',
#  'SA',
#  'SK',
#  'YK',
#  'YT'}

# %% [markdown]
# Ezek szerint egyrészt, az ```ufos``` táblában vannak hibás, vagy más országhoz tartozó rövidítések is. Másrészt, van ahol nem nagy betűvel van írva California állam rövidítése.

# %%
ufos[ufos['state'] == 'Ca'] = 'CA'
ufos[ufos['state'] == ''] = None

# %% [markdown]
# Összefésülöm az UFO észleléseket a városok neve és az államok rövidítései mentén a ```mdata``` (merged data) táblába.

# %%
mdata = pd.merge(ufos, cities, left_on=['city_cleaned', 'state'], right_on=['city', 'state_id']).drop(columns=['city_y', 'state'])
mdata.head()
# Out:
#   city_x            date     duration   posted     shape          date_parsed  \
# 0  Paola   11/9/17 01:00      2 hours  11/9/17    Circle  2017-11-09 01:00:00
# 1  Paola    9/1/99 21:00    <1 minute   9/9/13     Cigar  1999-09-01 21:00:00
# 2  Paola   7/16/10 19:30   40 Minutes  7/19/10     Cigar  2010-07-16 19:30:00
# 3  Paola    2/9/06 05:45  3-5 minutes  3/11/06   Unknown  2006-02-09 05:45:00
# 4  Paola  12/15/04 09:00        2 min  1/11/05  Triangle  2004-12-15 09:00:00
#
#   city_cleaned city_ascii state_id state_name county_name      lat      lng  \
# 0        Paola      Paola       KS     Kansas       Miami  38.5783 -94.8626
# 1        Paola      Paola       KS     Kansas       Miami  38.5783 -94.8626
# 2        Paola      Paola       KS     Kansas       Miami  38.5783 -94.8626
# 3        Paola      Paola       KS     Kansas       Miami  38.5783 -94.8626
# 4        Paola      Paola       KS     Kansas       Miami  38.5783 -94.8626
#
#    population  population_proper  density  incorporated         timezone
# 0      5366.0             5568.0    441.0          True  America/Chicago
# 1      5366.0             5568.0    441.0          True  America/Chicago
# 2      5366.0             5568.0    441.0          True  America/Chicago
# 3      5366.0             5568.0    441.0          True  America/Chicago
# 4      5366.0             5568.0    441.0          True  America/Chicago

# %% [markdown]
# Az előbbi lépésben előállítottam a két tábla metszetét a két-két attribútum mentén (inner join). Kérdés, hogy hány észlelés maradt így.

# %%
print('Az eredeti észlelés tábla mérete:', len(ufos))
print('A városokkal összefésült tábla mérete:', len(mdata))
print('Maradt %:', len(mdata)/len(ufos))
# Out:
# Az eredeti észlelés tábla mérete: 113319
# A városokkal összefésült tábla mérete: 82544
# Maradt %: 0.7284215356648047

# %% [markdown]
# Az eredeti halmaz mintegy negyedét elveszítettem, de a maradék legalább biztosan amerikai város, amelyekhez tartozik hely és lakosság sűrűség információ.

# %% [markdown]
# ### Az UFO észlelések száma a népsűrűség függvényében
#
# Feltételezem, hogy az UFO észlelések száma korrelál a népsűrűséggel, ezért normálom az észlelések számát a sűrűséggel.
#
# Az észleléseket csoportosítom a települések szerint és meghatározom az egyes csoportok számát. Az eredményt ```DataFrame``` táblává alakítom.

# %%
ufos_seen = pd.DataFrame(mdata.groupby(['state_id', 'city_cleaned']).size(), columns=['seen_count'])
ufos_seen.head()
# Out:
#                        seen_count
# state_id city_cleaned
# AK       Adak                   2
#          Anchor Point           3
#          Anchorage            130
#          Angoon                 1
#          Auke Bay               2

# %% [markdown]
# Azért hogy ki tudjam egészíteni az észlelések számát a sűrűség adatokkal, összefésülöm (újra) a ```cities``` táblával, majd pedig újraindexelem a kapott táblát, hogy továbbra is a ```state_id``` és a ```city``` legyenek a kulcsok.

# %%
ufos_seen = pd.merge(ufos_seen, cities, left_index=True, right_on=['state_id', 'city'])
ufos_seen.set_index(['state_id', 'city'], inplace=True)
ufos_seen[['seen_count', 'density']].head()
# Out:
#                        seen_count  density
# state_id city
# AK       Adak                   2      3.0
#          Anchor Point           3     59.1
#          Anchorage            130     67.0
#          Angoon                 1      7.0
#          Auke Bay               2    470.1

# %% [markdown]
# A következőekben el szeretném osztani a ```density``` változó értékét. Ezért ellenőrzöm, hogy nem 0-e, hogy ne kapjak ```Inf``` értékeket.

# %%
ufos_seen[ufos_seen['density'] == 0.0][['seen_count', 'density']]
# Out:
#                           seen_count  density
# state_id city
# AK       Cold Bay                  1      0.0
#          Wrangell                  3      0.0
# CA       Bucks Lake                1      0.0
# FL       Bay Lake                  1      0.0
# OR       White City                5      0.0
# PA       King of Prussia           5      0.0

# %% [markdown]
# A talált rekordokat eldobom.

# %%
ufos_seen = ufos_seen[ufos_seen['density'] != 0.0]

# %% [markdown]
# Mivel a népesség adatok nem állnak rendelkezésre minden város esetében, ezért az UFO észlelések számát a népsűrűség változóval normálom.

# %%
ufos_seen['ufos_seen_by_density'] = ufos_seen['seen_count'] / ufos_seen['density']
ufos_seen[['seen_count', 'density', 'ufos_seen_by_density']].head()
# Out:
#                        seen_count  density  ufos_seen_by_density
# state_id city
# AK       Adak                   2      3.0              0.666667
#          Anchor Point           3     59.1              0.050761
#          Anchorage            130     67.0              1.940299
#          Angoon                 1      7.0              0.142857
#          Auke Bay               2    470.1              0.004254

# %% [markdown]
# Mivel az UFO-k feltehetőleg rendkívül látványos jelenségek, ott ahol tényleg láttak egyet, ott valószínűleg több ember is jelentette. Ezért először rendezem az adatokat a terület/ember-re jutó UFO észlelések száma szerint ```ufos_seen_by_density```, majd pedig megnézem hogy melyek a legnagyobb ilyen települések, amelyeket kiteszek a térképre.

# %%
cities_with_most_ufos = ufos_seen.sort_values(by='ufos_seen_by_density', ascending=False).iloc[:500, :]
cities_with_most_ufos[['seen_count', 'density', 'ufos_seen_by_density']].head(10)
# Out:
#                            seen_count  density  ufos_seen_by_density
# state_id city
# FL       Merritt Island            23      0.1            230.000000
# AK       Nelchina                   1      0.1             10.000000
# FL       Lake Buena Vista           7      1.0              7.000000
# CA       Caribou                    1      0.2              5.000000
# AK       Juneau                    17      4.0              4.250000
# FL       Yeehaw Junction            4      1.1              3.636364
# AK       Sitka                      3      1.0              3.000000
# PA       Dingmans Ferry             5      1.8              2.777778
# NV       Valmy                      1      0.4              2.500000
# AZ       Sanders                    2      0.8              2.500000

# %% [markdown]
# A 500 legnépszerűbb UFO látogatási hely közül kiválaszom a legnagyobb városokat, amelyeket feltszek a térképre.
#
# A térképen a pontok méretét az UFO észlelések lakosságra vett sűrűségének a logaritmusa adja, a pontok színét pedig az abszolút száma az észleléseknek. Ehhez szükség van néhány további változóra...

# %%
log_dens = pd.np.log(cities_with_most_ufos['ufos_seen_by_density'])
scaled_log_dens = MinMaxScaler(copy=True, feature_range=(5,15)).fit_transform(log_dens.reshape(-1, 1)).reshape(-1)
density_str = cities_with_most_ufos['ufos_seen_by_density'].round(2).astype(str)
density_info = cities_with_most_ufos['city_ascii'] + ' (Density: ' + density_str + ') '
# Out:
# c:\program files\python35\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %% [markdown]
# Az alábbi kódrészlet nagyrészt a Plotly oldaláról van átvéve: https://plot.ly/python/scatter-plots-on-maps/

# %%
colorscale = [
    [0, "rgb(5, 10, 172)"],
    [0.35, "rgb(40, 60, 190)"],
    [0.5, "rgb(70, 100, 245)"],
    [0.6, "rgb(90, 120, 245)"],
    [0.7, "rgb(106, 137, 247)"],
    [1, "rgb(220, 220, 220)"]
]

data = [{
    'type': 'scattergeo',
    'locationmode': 'USA-states',
    'lon': cities_with_most_ufos['lng'],
    'lat': cities_with_most_ufos['lat'],
    'text': density_info,
    'mode': 'markers',
    'marker': {
        'size': scaled_log_dens,
        'opacity': 0.8,
        'reversescale': True,
        'autocolorscale': False,
        'symbol': 'circle',
        'line': {
            'width': 1,
            'color': 'rgba(102, 102, 102)',
        },
        'colorscale': colorscale,
        'cmin': 0,
        'color': cities_with_most_ufos['seen_count'],
        'cmax': cities_with_most_ufos['seen_count'].max(),
        'colorbar': {
            'title': 'Ufos seen',
        },
    }
}]

layout = {
    'title': 'UFO reports in the USA',
    'colorbar': True,
    'geo': {
        'scope': 'usa',
        'projection': { 
            'type': 'albers usa',
        },
        'showland': True,
        'landcolor': "rgb(250, 250, 250)",
        'subunitcolor': "rgb(217, 217, 217)",
        'countrycolor': "rgb(217, 217, 217)",
        'countrywidth': 0.5,
        'subunitwidth': 0.5,
    },
}

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='ufos' )
# Out:
# <div id="9b3009f2-63d1-497e-9549-340abe8d2163" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9b3009f2-63d1-497e-9549-340abe8d2163", [{"type": "scattergeo", "lat": [28.3146, 61.9991, 28.3793, 40.0762, 58.4566, 27.6993, 57.2405, 41.2201, 40.7718, 35.2095, 35.835, 32.9662, 40.276, 45.902, 32.3482, 63.3523, 33.7378, 61.1508, 33.8544, 40.5927, 47.2379, 32.8209, 30.2285, 61.8154, 45.2592, 33.1879, 28.517, 36.6438, 44.8994, 63.9454, 35.2172, 59.7958, 39.3772, 34.9901, 38.2543, 33.4318, 41.1418, 47.9082, 35.425, 30.5127, 37.6509, 40.8541, 51.8768, 34.5578, 35.2769, 34.7439, 47.6445, 40.0871, 36.1756, 35.6667, 33.427, 34.8899, 29.787, 32.7553, 33.6618, 43.6135, 48.1122, 45.3514, 33.5722, 38.3551, 29.4198, 33.241, 64.7026, 31.6671, 34.9178, 33.7095, 30.3322, 48.6338, 36.2702, 41.3762, 35.206, 47.3069, 32.1558, 36.2488, 34.8574, 42.4419, 29.4952, 44.7411, 37.3547, 37.6431, 40.8101, 47.0061, 33.8225, 38.1367, 45.1143, 61.0961, 47.1694, 33.8012, 38.4517, 41.5761, 33.9116, 37.9702, 29.8899, 45.5153, 28.4801, 35.1316, 33.0093, 33.2823, 38.933, 37.5803, 30.8899, 36.2288, 33.6872, 39.6357, 30.9335, 30.826, 34.0052, 36.1714, 35.1055, 40.7774, 33.8513, 32.8312, 41.7001, 38.8394, 35.4677, 45.5372, 29.7871, 32.9416, 35.7735, 33.2613, 33.5395, 58.4274, 34.2677, 32.4783, 45.4111, 33.492, 33.488, 30.0613, 35.8407, 30.3038, 44.4997, 33.9298, 44.5847, 34.34, 36.2901, 38.4425, 29.9769, 30.6285, 33.9011, 31.575, 34.8259, 36.5732, 45.0243, 40.4041, 38.8673, 31.5631, 60.5361, 33.6675, 30.0336, 47.6217, 34.0286, 30.2903, 39.7771, 32.599, 56.0042, 41.9371, 39.1239, 48.981, 36.7335, 47.7626, 48.071, 38.1662, 60.7152, 45.2006, 31.4384, 36.1284, 64.0603, 35.208, 35.1598, 39.0217, 61.5266, 35.8168, 37.1492, 38.9813, 36.2704, 64.8353, 34.699, 33.8829, 45.5541, 35.9412, 37.1283, 39.5487, 47.5436, 32.907, 31.9157, 34.2164, 29.4722, 33.9433, 34.587, 60.9425, 44.0773, 47.6591, 35.5151, 46.2612, 38.2934, 30.3917, 31.4704, 47.3572, 27.0673, 40.7944, 37.047, 38.4684, 34.955, 36.7359, 38.0423, 34.5006, 62.1278, 47.8373, 33.7844, 34.0175, 36.3813, 35.8709, 47.9167, 37.0755, 33.0447, 35.6619, 38.693, 45.9632, 30.237, 33.3644, 35.969, 33.0918, 45.3517, 60.7905, 34.0366, 24.6746, 32.7876, 34.4627, 41.0934, 37.0329, 32.64, 40.811, 36.6953, 38.9445, 35.0722, 48.4288, 38.7591, 33.9823, 39.7621, 33.4016, 36.6778, 38.4221, 47.3981, 30.1391, 44.5606, 38.5904, 47.6671, 28.7877, 39.1512, 33.6802, 38.8664, 30.7697, 43.4445, 57.4563, 37.081, 34.616, 39.9859, 27.9937, 45.9976, 35.1047, 37.0982, 35.4855, 36.63, 32.3265, 38.5666, 40.5698, 32.4355, 33.0267, 36.7546, 46.1851, 34.4936, 34.0563, 42.2594, 34.114, 46.5351, 36.7767, 39.4055, 37.9287, 33.7293, 36.7438, 32.9861, 35.2335, 32.8137, 29.2991, 46.5257, 44.3341, 39.0742, 39.5612, 34.8272, 33.9385, 42.9082, 34.5771, 29.8158, 34.2068, 32.7321, 46.4855, 34.2329, 37.6882, 30.5771, 26.644, 45.0508, 64.5392, 33.0315, 45.6352, 36.4319, 35.7498, 33.6591, 60.0745, 37.5995, 36.2679, 36.8201, 35.0847, 35.2168, 33.5276, 39.6314, 37.6894, 34.4364, 43.958, 61.5769, 32.7938, 38.1375, 31.9051, 47.6402, 32.561, 41.2634, 35.3528, 39.6423, 29.1803, 32.6692, 32.9595, 39.4597, 35.9475, 39.7168, 26.1504, 35.1578, 34.5983, 33.9551, 38.9475, 39.832, 34.5799, 33.3987, 37.7084, 45.208, 38.7563, 35.1867, 35.3339, 45.254, 34.3744, 37.1943, 41.5671, 47.829, 46.6868, 36.5663, 46.8662, 37.302, 32.0282, 34.6931, 44.9231, 44.1917, 33.1851, 47.9524, 40.6722, 64.7532, 38.201, 35.0431, 35.9639, 60.1135, 33.7112, 47.2431, 27.0577, 35.0657, 45.6928, 34.8655, 31.8478, 48.6977, 34.7593, 35.2331, 37.92, 32.51, 33.7627, 39.7035, 34.8804, 62.6294, 26.612, 29.1959, 43.161, 40.724, 46.6087, 36.5011, 34.5699, 46.7602, 41.0885, 26.7468, 39.033, 27.7173, 36.1836, 41.9667, 32.7813, 47.8597, 34.816, 44.2723, 45.6284, 35.1205, 35.6689, 37.0595, 40.0736, 39.9348, 41.7829, 33.1021, 38.4997, 35.2873,  ...
